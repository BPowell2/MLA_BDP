# %%
import pandas as pd

# %%
test = "hello"
print(test)
# Out:
# hello

# %%
df = pd.read_csv("weather_2012.csv")
#first 5 rows
df.head()
# Out:
#              Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0  2012-01-01 00:00:00      -1.8                -3.9           86
# 1  2012-01-01 01:00:00      -1.8                -3.7           87
# 2  2012-01-01 02:00:00      -1.8                -3.4           89
# 3  2012-01-01 03:00:00      -1.5                -3.2           88
# 4  2012-01-01 04:00:00      -1.5                -3.3           88
#
#    Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather
# 0                4              8.0           101.24                   Fog
# 1                4              8.0           101.24                   Fog
# 2                7              4.0           101.26  Freezing Drizzle,Fog
# 3                6              4.0           101.27  Freezing Drizzle,Fog
# 4                7              4.8           101.23                   Fog

# %%
#last 5 rows
df.tail()
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 8779  2012-12-31 19:00:00       0.1                -2.7           81
# 8780  2012-12-31 20:00:00       0.2                -2.4           83
# 8781  2012-12-31 21:00:00      -0.5                -1.5           93
# 8782  2012-12-31 22:00:00      -0.2                -1.8           89
# 8783  2012-12-31 23:00:00       0.0                -2.1           86
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa) Weather
# 8779               30              9.7           100.13    Snow
# 8780               24              9.7           100.03    Snow
# 8781               28              4.8            99.95    Snow
# 8782               28              9.7            99.91    Snow
# 8783               30             11.3            99.89    Snow

# %%
#random 5 rows
df.sample(5)
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 4105  2012-06-20 01:00:00      25.0                18.5           67
# 5216  2012-08-05 08:00:00      26.5                21.0           72
# 3559  2012-05-28 07:00:00      16.6                 6.2           50
# 7328  2012-11-01 08:00:00       7.2                 4.5           83
# 7527  2012-11-09 15:00:00       4.6                -2.0           62
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)        Weather
# 4105               19             25.0           100.87   Mainly Clear
# 5216               24             24.1           100.80         Cloudy
# 3559               22             48.3           101.26  Mostly Cloudy
# 7328                9             24.1            99.33           Rain
# 7527               24             24.1           101.29         Cloudy

# %%
#show all columns in the dataset
df
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0     2012-01-01 00:00:00      -1.8                -3.9           86
# 1     2012-01-01 01:00:00      -1.8                -3.7           87
# 2     2012-01-01 02:00:00      -1.8                -3.4           89
# 3     2012-01-01 03:00:00      -1.5                -3.2           88
# 4     2012-01-01 04:00:00      -1.5                -3.3           88
# ...                   ...       ...                 ...          ...
# 8779  2012-12-31 19:00:00       0.1                -2.7           81
# 8780  2012-12-31 20:00:00       0.2                -2.4           83
# 8781  2012-12-31 21:00:00      -0.5                -1.5           93
# 8782  2012-12-31 22:00:00      -0.2                -1.8           89
# 8783  2012-12-31 23:00:00       0.0                -2.1           86
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather
# ...

# %%
df=df.rename(columns={"Date/Time":"date_time","Temp (C)":"temp_c","Dew Point Temp (C)":"dew_point","Rel Hum (%)":"realtive_humitity","Wind Spd (km/h)":"wind_speed","Visibility (km)":"visibility","Stn Press (kPa)":"pressure","Weather":"weather"})
df
# Out:
#                 date_time  temp_c  dew_point  realtive_humitity  wind_speed  \
# 0     2012-01-01 00:00:00    -1.8       -3.9                 86           4
# 1     2012-01-01 01:00:00    -1.8       -3.7                 87           4
# 2     2012-01-01 02:00:00    -1.8       -3.4                 89           7
# 3     2012-01-01 03:00:00    -1.5       -3.2                 88           6
# 4     2012-01-01 04:00:00    -1.5       -3.3                 88           7
# ...                   ...     ...        ...                ...         ...
# 8779  2012-12-31 19:00:00     0.1       -2.7                 81          30
# 8780  2012-12-31 20:00:00     0.2       -2.4                 83          24
# 8781  2012-12-31 21:00:00    -0.5       -1.5                 93          28
# 8782  2012-12-31 22:00:00    -0.2       -1.8                 89          28
# 8783  2012-12-31 23:00:00     0.0       -2.1                 86          30
#
#       visibility  pressure               weather
# ...

# %%
# find count mean ect for columns
df.describe()
# Out:
#             temp_c    dew_point  realtive_humitity   wind_speed   visibility  \
# count  8784.000000  8784.000000        8784.000000  8784.000000  8784.000000
# mean      8.798144     2.555294          67.431694    14.945469    27.664447
# std      11.687883    10.883072          16.918881     8.688696    12.622688
# min     -23.300000   -28.500000          18.000000     0.000000     0.200000
# 25%       0.100000    -5.900000          56.000000     9.000000    24.100000
# 50%       9.300000     3.300000          68.000000    13.000000    25.000000
# 75%      18.800000    11.800000          81.000000    20.000000    25.000000
# max      33.000000    24.400000         100.000000    83.000000    48.300000
#
#           pressure
# count  8784.000000
# mean    101.051623
# std       0.844005
# min      97.520000
# 25%     100.560000
# 50%     101.070000
# 75%     101.590000
# max     103.650000

# %%
#convert c to f
df["temp_f"]=df_test["temp_c"]*1.8+32
df
# Out:
#                 date_time  temp_c  dew_point  realtive_humitity  wind_speed  \
# 0     2012-01-01 00:00:00    -1.8       -3.9                 86           4
# 1     2012-01-01 01:00:00    -1.8       -3.7                 87           4
# 2     2012-01-01 02:00:00    -1.8       -3.4                 89           7
# 3     2012-01-01 03:00:00    -1.5       -3.2                 88           6
# 4     2012-01-01 04:00:00    -1.5       -3.3                 88           7
# ...                   ...     ...        ...                ...         ...
# 8779  2012-12-31 19:00:00     0.1       -2.7                 81          30
# 8780  2012-12-31 20:00:00     0.2       -2.4                 83          24
# 8781  2012-12-31 21:00:00    -0.5       -1.5                 93          28
# 8782  2012-12-31 22:00:00    -0.2       -1.8                 89          28
# 8783  2012-12-31 23:00:00     0.0       -2.1                 86          30
#
#       visibility  pressure               weather  temp_f
# ...

# %%
#changing temp f to go before temp c
col_name=list(df.columns)
col_name
# Out:
# ['date_time',
#  'temp_c',
#  'dew_point',
#  'realtive_humitity',
#  'wind_speed',
#  'visibility',
#  'pressure',
#  'weather',
#  'temp_f']

# %%
col_name[0],col_name[8]=col_name[8],col_name[0]
col_name[8]
# Out:
# 'date_time'

# %%
# changing position of data and time and temp_f
df = df[col_name]
df
# Out:
#       temp_f  temp_c  dew_point  realtive_humitity  wind_speed  visibility  \
# 0      28.76    -1.8       -3.9                 86           4         8.0
# 1      28.76    -1.8       -3.7                 87           4         8.0
# 2      28.76    -1.8       -3.4                 89           7         4.0
# 3      29.30    -1.5       -3.2                 88           6         4.0
# 4      29.30    -1.5       -3.3                 88           7         4.8
# ...      ...     ...        ...                ...         ...         ...
# 8779   32.18     0.1       -2.7                 81          30         9.7
# 8780   32.36     0.2       -2.4                 83          24         9.7
# 8781   31.10    -0.5       -1.5                 93          28         4.8
# 8782   31.64    -0.2       -1.8                 89          28         9.7
# 8783   32.00     0.0       -2.1                 86          30        11.3
#
#       pressure               weather            date_time
# ...

# %%
#printing out the type of each column
df.dtypes
# Out:
# temp_f               float64
# temp_c               float64
# dew_point            float64
# realtive_humitity      int64
# wind_speed             int64
# visibility           float64
# pressure             float64
# weather               object
# date_time             object
# dtype: object

# %%
#convert date and time
df["date_time"] = pd.to_datetime(df["date_time"])
df.dtypes
# Out:
# temp_f                      float64
# temp_c                      float64
# dew_point                   float64
# realtive_humitity             int64
# wind_speed                    int64
# visibility                  float64
# pressure                    float64
# weather                      object
# date_time            datetime64[ns]
# dtype: object

# %%
#monthly_avg=df["temp_f"].mean()
#monthly_avg
#series=pd.Series(monthly_avg)
#series
monthly_avg=df["date_time"].dt.month_name()
series=monthly_avg
series
# Out:
# 0        January
# 1        January
# 2        January
# 3        January
# 4        January
#           ...
# 8779    December
# 8780    December
# 8781    December
# 8782    December
# 8783    December
# Name: date_time, Length: 8784, dtype: object

# %%
#df_test=df
#df_test["date_time"].dt.month_name()

# %%
#plot temp vs realtive humiity 
import seaborn as sns
sns.scatterplot(x=df["temp_f"],y=df["realtive_humitity"])
# Out:
# <Axes: xlabel='temp_f', ylabel='realtive_humitity'>

# %%
#line plot of average temp per month
sns.lineplot(x=df["temp_f"],y=series)
# Out:
# <Axes: xlabel='temp_f', ylabel='date_time'>

# %% [markdown]
# i was unsure how to get the average of each partiular month after converting the datatype to a datetime data type

# %%
#boxplot 
sns.boxplot(df)
# Out:
# <Axes: >
